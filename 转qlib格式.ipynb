# %%
import qlib
from qlib.data import D
from qlib.data.dataset.handler import DataHandlerLP
from qlib.data.data import Cal
from qlib.data.filter import NameDFilter
import pandas as pd
import os
import subprocess
import requests
import json
import time

# %%
'''
从DW（数仓）中下载数据，1min，1day，根据需求自行下载，一般下载一次即可
'''
# 设置token
headers = {"token": "wanglei@hztantra.com.cn"}  # your token

# %%
# 把返回的json格式数据解析程dataframe格式，retCode=200表示成功，其他值均表示失败，失败原因查看retMsg
def parse_json_data_to_dataframe(ret_data: None):
    bl = True
    msg = None
    df_lt = []
    if ret_data["retCode"] == 200:
        data_json = json.loads(ret_data["retData"])
        # 将提取的结果转换为DataFrame
        if "columns" in data_json.keys():
            df = pd.DataFrame.from_dict(data_json["data"])
            df.columns = data_json["columns"]
            df_lt.append(df)
        else:
            for key in data_json.keys():
                print(key)
                json_data = json.loads(data_json[key])
                if "data" in json_data.keys():
                    df = pd.DataFrame.from_dict(json_data["data"])
                    df.columns = json_data["columns"]
                    df_lt.append(df)
                else:
                    for ky in json_data.keys():
                        try:
                            j_data = json.loads(json_data[ky])
                            df = pd.DataFrame.from_dict(j_data["data"])
                            df.columns = j_data["columns"]
                            df_lt.append(df)
                        except:
                            # 再深层次自行解析
                            pass
    else:
        msg = ret_data["retMsg"]
        bl = False
    return bl, msg, df_lt


# 上传/请求数据函数
def post_data(url: str = None, datas: dict = None):
    r = requests.post(url=url, headers=headers, data=json.dumps(datas))
    return r.json()


# 获取数据函数
def get_data(url: str = None):
    r = requests.get(url=url, headers=headers)
    return r.json()

# %%
'''
其中
tr_code: 符合000001.SZ格式
start_time: 开始时间，格式为YYYYMMDDHHMMSS
end_time: 结束时间，格式为YYYYMMDDHHMMSS
k_type: 数据类型，1min表示1分钟数据，1day表示1天数据
adj_type: 复权类型，f表示前复权，b表示后复权
'''

# 只取可转债数据
code_table_df = pd.read_csv('D:/data/STKInfo/BOND_ConvertInfo.csv')
cb_code_list = code_table_df['SYMBOL9'].tolist()

# 重试参数
max_retries = 5
backoff_factor = 1  # 基础等待秒数，指数退避会以此为基数

for code in cb_code_list:
    print(f'正在处理：{code}...')
    url = f"http://hztantra.synology.me:8000/v1/api/market/get_history.json?tr_code={code}&start_time=20220101&end_time=20250707&k_type=1day&adj_type=f"

    # 带重试的请求，避免 ConnectionResetError 导致整个流程中断
    ret_data = None
    for attempt in range(max_retries):
        try:
            resp = requests.get(url, headers=headers, timeout=15)
            resp.raise_for_status()
            ret_data = resp.json()
            break
        except requests.exceptions.RequestException as e:
            print(f"请求失败（{code}）attempt {attempt+1}/{max_retries}: {e}")
            if attempt < max_retries - 1:
                sleep_time = backoff_factor * (2 ** attempt)
                print(f"等待 {sleep_time} 秒后重试...")
                time.sleep(sleep_time)
            else:
                print(f"达到最大重试次数，跳过 {code}")
    if ret_data is None:
        # 未获取到数据则跳过当前 code
        continue

    # 返回数据解析成DataFrame
    try:
        bl, msg, df_lt = parse_json_data_to_dataframe(ret_data=ret_data)
        if bl:
            for df in df_lt:
                df.to_csv(f'D:/data/day1_data_raw/{code}.csv', index=False)
        else:
            print(msg)
    except Exception as ex:
        print(f'数据解析失败（{code}）: {ex}')
        continue
# Out:
# 正在处理：110025.SH...
# 请求失败（110025.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110025.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110025.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110025.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110025.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110025.SH
# 正在处理：110027.SH...
# 请求失败（110027.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110027.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110027.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110027.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110027.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110027.SH
# 正在处理：110028.SH...
# 请求失败（110028.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110028.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110028.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110028.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110028.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110028.SH
# 正在处理：110029.SH...
# 请求失败（110029.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110029.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110029.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110029.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110029.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110029.SH
# 正在处理：110031.SH...
# 请求失败（110031.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110031.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110031.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110031.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110031.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110031.SH
# 正在处理：110032.SH...
# 请求失败（110032.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110032.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110032.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110032.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110032.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110032.SH
# 正在处理：110033.SH...
# 请求失败（110033.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110033.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110033.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110033.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110033.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110033.SH
# 正在处理：110034.SH...
# 请求失败（110034.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110034.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110034.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110034.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110034.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110034.SH
# 正在处理：110035.SH...
# 请求失败（110035.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110035.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110035.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110035.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110035.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110035.SH
# 正在处理：110038.SH...
# 请求失败（110038.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110038.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110038.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110038.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110038.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110038.SH
# 正在处理：110039.SH...
# 请求失败（110039.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110039.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110039.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110039.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110039.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110039.SH
# 正在处理：110040.SH...
# 请求失败（110040.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110040.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110040.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110040.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110040.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110040.SH
# 正在处理：110041.SH...
# 请求失败（110041.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110041.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110041.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110041.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110041.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110041.SH
# 正在处理：110042.SH...
# 请求失败（110042.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110042.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110042.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110042.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110042.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110042.SH
# 正在处理：110043.SH...
# 请求失败（110043.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110043.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110043.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110043.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110043.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110043.SH
# 正在处理：110044.SH...
# 请求失败（110044.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110044.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110044.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110044.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110044.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110044.SH
# 正在处理：110045.SH...
# 请求失败（110045.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110045.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110045.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110045.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110045.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110045.SH
# 正在处理：110046.SH...
# 请求失败（110046.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110046.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110046.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110046.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110046.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110046.SH
# 正在处理：110047.SH...
# 请求失败（110047.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110047.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110047.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110047.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110047.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110047.SH
# 正在处理：110048.SH...
# 请求失败（110048.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110048.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110048.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110048.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110048.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110048.SH
# 正在处理：110049.SH...
# 请求失败（110049.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110049.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110049.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110049.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110049.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110049.SH
# 正在处理：110050.SH...
# 请求失败（110050.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110050.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110050.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110050.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110050.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110050.SH
# 正在处理：110051.SH...
# 请求失败（110051.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110051.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110051.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110051.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110051.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110051.SH
# 正在处理：110052.SH...
# 请求失败（110052.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110052.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110052.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110052.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110052.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110052.SH
# 正在处理：110053.SH...
# 请求失败（110053.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110053.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110053.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110053.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110053.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110053.SH
# 正在处理：110054.SH...
# 请求失败（110054.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110054.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110054.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110054.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110054.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110054.SH
# 正在处理：110055.SH...
# 请求失败（110055.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110055.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110055.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110055.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110055.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110055.SH
# 正在处理：110056.SH...
# 请求失败（110056.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110056.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110056.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110056.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110056.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110056.SH
# 正在处理：110057.SH...
# 请求失败（110057.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110057.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110057.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110057.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110057.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110057.SH
# 正在处理：110058.SH...
# 请求失败（110058.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110058.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110058.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110058.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110058.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110058.SH
# 正在处理：110059.SH...
# 请求失败（110059.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110059.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110059.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110059.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110059.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110059.SH
# 正在处理：110060.SH...
# 请求失败（110060.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110060.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110060.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110060.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110060.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110060.SH
# 正在处理：110061.SH...
# 请求失败（110061.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110061.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110061.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110061.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110061.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110061.SH
# 正在处理：110062.SH...
# 请求失败（110062.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110062.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110062.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110062.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110062.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110062.SH
# 正在处理：110063.SH...
# 请求失败（110063.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110063.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110063.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110063.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110063.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110063.SH
# 正在处理：110064.SH...
# 请求失败（110064.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110064.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110064.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110064.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110064.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110064.SH
# 正在处理：110065.SH...
# 请求失败（110065.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110065.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110065.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110065.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110065.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110065.SH
# 正在处理：110066.SH...
# 请求失败（110066.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# 请求失败（110066.SH）attempt 2/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 2 秒后重试...
# 请求失败（110066.SH）attempt 3/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 4 秒后重试...
# 请求失败（110066.SH）attempt 4/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 8 秒后重试...
# 请求失败（110066.SH）attempt 5/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 达到最大重试次数，跳过 110066.SH
# 正在处理：110067.SH...
# 请求失败（110067.SH）attempt 1/5: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# 等待 1 秒后重试...
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#      24 for attempt in range(max_retries):
#      25     try:
# ---> 26         resp = requests.get(url, headers=headers, timeout=15)
#      27         resp.raise_for_status()
#      28         ret_data = resp.json()
#
# File d:\data\.venv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\data\.venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\data\.venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\data\.venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\data\.venv\lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File d:\data\.venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\data\.venv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\data\.venv\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
'''
# 将原始数据转换成中间数据（csv）
'''
features = ['datetime','instrument','open','high','low','close','volume','amount']#,'marketcap','new','ST','CONVERTIBLEPREMIUMRATE']#,'pre_close','TURNOVERRATE','new','ST']
for csvname in os.listdir('min1_data_raw'):
    instrument = csvname[:9]
    print(f"正在转换中间文件：{instrument}...")
    df_tmp = pd.read_csv(f'min1_data_raw/{instrument}.csv')
    df_tmp['datetime'] = pd.to_datetime(df_tmp['date'] * 10000 + df_tmp['time'], format='%Y%m%d%H%M')#pd.to_datetime(df_tmp['date'], format='%Y-%m-%d')
    df_tmp['instrument'] = instrument
    df_tmp = df_tmp[features]
    df_tmp.set_index(['datetime', 'instrument'], inplace=True)
    df_tmp.to_csv(f'min1_data_mid/{instrument}.csv')
# Out:
# 正在转换中间文件：110034.SH...
# 正在转换中间文件：110038.SH...
# 正在转换中间文件：110043.SH...
# 正在转换中间文件：110044.SH...
# 正在转换中间文件：110045.SH...
# 正在转换中间文件：110047.SH...
# 正在转换中间文件：110048.SH...
# 正在转换中间文件：110052.SH...
# 正在转换中间文件：110053.SH...
# 正在转换中间文件：110055.SH...
# 正在转换中间文件：110056.SH...
# 正在转换中间文件：110057.SH...
# 正在转换中间文件：110058.SH...
# 正在转换中间文件：110059.SH...
# 正在转换中间文件：110060.SH...
# 正在转换中间文件：110061.SH...
# 正在转换中间文件：110062.SH...
# 正在转换中间文件：110063.SH...
# 正在转换中间文件：110064.SH...
# 正在转换中间文件：110066.SH...
# 正在转换中间文件：110067.SH...
# 正在转换中间文件：110068.SH...
# 正在转换中间文件：110070.SH...
# 正在转换中间文件：110071.SH...
# 正在转换中间文件：110072.SH...
# 正在转换中间文件：110073.SH...
# 正在转换中间文件：110074.SH...
# 正在转换中间文件：110075.SH...
# 正在转换中间文件：110076.SH...
# 正在转换中间文件：110077.SH...
# 正在转换中间文件：110079.SH...
# 正在转换中间文件：110080.SH...
# 正在转换中间文件：110081.SH...
# 正在转换中间文件：110082.SH...
# 正在转换中间文件：110083.SH...
# 正在转换中间文件：110084.SH...
# 正在转换中间文件：110085.SH...
# 正在转换中间文件：110086.SH...
# 正在转换中间文件：110087.SH...
# 正在转换中间文件：110088.SH...
# 正在转换中间文件：110089.SH...
# 正在转换中间文件：110090.SH...
# 正在转换中间文件：110091.SH...
# 正在转换中间文件：110092.SH...
# 正在转换中间文件：110093.SH...
# 正在转换中间文件：110094.SH...
# 正在转换中间文件：110095.SH...
# 正在转换中间文件：110096.SH...
# 正在转换中间文件：110097.SH...
# 正在转换中间文件：110098.SH...
# 正在转换中间文件：110802.SH...
# 正在转换中间文件：110803.SH...
# 正在转换中间文件：110804.SH...
# 正在转换中间文件：110807.SH...
# 正在转换中间文件：110808.SH...
# 正在转换中间文件：110810.SH...
# 正在转换中间文件：110812.SH...
# 正在转换中间文件：110814.SH...
# 正在转换中间文件：111000.SH...
# 正在转换中间文件：111001.SH...
# 正在转换中间文件：111002.SH...
# 正在转换中间文件：111003.SH...
# 正在转换中间文件：111004.SH...
# 正在转换中间文件：111005.SH...
# 正在转换中间文件：111006.SH...
# 正在转换中间文件：111007.SH...
# 正在转换中间文件：111008.SH...
# 正在转换中间文件：111009.SH...
# 正在转换中间文件：111010.SH...
# 正在转换中间文件：111011.SH...
# 正在转换中间文件：111012.SH...
# 正在转换中间文件：111013.SH...
# 正在转换中间文件：111014.SH...
# 正在转换中间文件：111015.SH...
# 正在转换中间文件：111016.SH...
# 正在转换中间文件：111017.SH...
# 正在转换中间文件：111018.SH...
# 正在转换中间文件：111019.SH...
# 正在转换中间文件：111020.SH...
# 正在转换中间文件：111021.SH...
# 正在转换中间文件：113009.SH...
# 正在转换中间文件：113011.SH...
# 正在转换中间文件：113013.SH...
# 正在转换中间文件：113016.SH...
# 正在转换中间文件：113017.SH...
# 正在转换中间文件：113021.SH...
# 正在转换中间文件：113024.SH...
# 正在转换中间文件：113025.SH...
# 正在转换中间文件：113026.SH...
# 正在转换中间文件：113027.SH...
# 正在转换中间文件：113030.SH...
# 正在转换中间文件：113033.SH...
# 正在转换中间文件：113034.SH...
# 正在转换中间文件：113036.SH...
# 正在转换中间文件：113037.SH...
# 正在转换中间文件：113039.SH...
# 正在转换中间文件：113042.SH...
# 正在转换中间文件：113043.SH...
# 正在转换中间文件：113044.SH...
# 正在转换中间文件：113045.SH...
# 正在转换中间文件：113046.SH...
# 正在转换中间文件：113047.SH...
# 正在转换中间文件：113048.SH...
# 正在转换中间文件：113049.SH...
# 正在转换中间文件：113050.SH...
# 正在转换中间文件：113051.SH...
# 正在转换中间文件：113052.SH...
# 正在转换中间文件：113053.SH...
# 正在转换中间文件：113054.SH...
# 正在转换中间文件：113055.SH...
# 正在转换中间文件：113056.SH...
# 正在转换中间文件：113057.SH...
# 正在转换中间文件：113058.SH...
# 正在转换中间文件：113059.SH...
# 正在转换中间文件：113060.SH...
# 正在转换中间文件：113061.SH...
# 正在转换中间文件：113062.SH...
# 正在转换中间文件：113063.SH...
# 正在转换中间文件：113064.SH...
# 正在转换中间文件：113065.SH...
# 正在转换中间文件：113066.SH...
# 正在转换中间文件：113067.SH...
# 正在转换中间文件：113068.SH...
# 正在转换中间文件：113069.SH...
# 正在转换中间文件：113070.SH...
# 正在转换中间文件：113502.SH...
# 正在转换中间文件：113504.SH...
# 正在转换中间文件：113505.SH...
# 正在转换中间文件：113516.SH...
# 正在转换中间文件：113519.SH...
# 正在转换中间文件：113524.SH...
# 正在转换中间文件：113525.SH...
# 正在转换中间文件：113526.SH...
# 正在转换中间文件：113527.SH...
# 正在转换中间文件：113530.SH...
# 正在转换中间文件：113532.SH...
# 正在转换中间文件：113534.SH...
# 正在转换中间文件：113535.SH...
# 正在转换中间文件：113537.SH...
# 正在转换中间文件：113541.SH...
# 正在转换中间文件：113542.SH...
# 正在转换中间文件：113545.SH...
# 正在转换中间文件：113546.SH...
# 正在转换中间文件：113548.SH...
# 正在转换中间文件：113549.SH...
# 正在转换中间文件：113550.SH...
# 正在转换中间文件：113561.SH...
# 正在转换中间文件：113563.SH...
# 正在转换中间文件：113565.SH...
# 正在转换中间文件：113566.SH...
# 正在转换中间文件：113567.SH...
# 正在转换中间文件：113568.SH...
# 正在转换中间文件：113569.SH...
# 正在转换中间文件：113570.SH...
# 正在转换中间文件：113573.SH...
# 正在转换中间文件：113574.SH...
# 正在转换中间文件：113575.SH...
# 正在转换中间文件：113576.SH...
# 正在转换中间文件：113577.SH...
# 正在转换中间文件：113578.SH...
# 正在转换中间文件：113579.SH...
# 正在转换中间文件：113582.SH...
# 正在转换中间文件：113584.SH...
# 正在转换中间文件：113585.SH...
# 正在转换中间文件：113588.SH...
# 正在转换中间文件：113589.SH...
# 正在转换中间文件：113591.SH...
# 正在转换中间文件：113593.SH...
# 正在转换中间文件：113594.SH...
# 正在转换中间文件：113595.SH...
# 正在转换中间文件：113596.SH...
# 正在转换中间文件：113597.SH...
# 正在转换中间文件：113598.SH...
# 正在转换中间文件：113599.SH...
# 正在转换中间文件：113600.SH...
# 正在转换中间文件：113601.SH...
# 正在转换中间文件：113602.SH...
# 正在转换中间文件：113604.SH...
# 正在转换中间文件：113605.SH...
# 正在转换中间文件：113606.SH...
# 正在转换中间文件：113608.SH...
# 正在转换中间文件：113609.SH...
# 正在转换中间文件：113610.SH...
# 正在转换中间文件：113615.SH...
# 正在转换中间文件：113616.SH...
# 正在转换中间文件：113618.SH...
# 正在转换中间文件：113619.SH...
# 正在转换中间文件：113620.SH...
# 正在转换中间文件：113621.SH...
# 正在转换中间文件：113622.SH...
# 正在转换中间文件：113623.SH...
# 正在转换中间文件：113624.SH...
# 正在转换中间文件：113625.SH...
# 正在转换中间文件：113626.SH...
# 正在转换中间文件：113627.SH...
# 正在转换中间文件：113628.SH...
# 正在转换中间文件：113629.SH...
# 正在转换中间文件：113630.SH...
# 正在转换中间文件：113631.SH...
# 正在转换中间文件：113632.SH...
# 正在转换中间文件：113633.SH...
# 正在转换中间文件：113634.SH...
# 正在转换中间文件：113635.SH...
# 正在转换中间文件：113636.SH...
# 正在转换中间文件：113637.SH...
# 正在转换中间文件：113638.SH...
# 正在转换中间文件：113639.SH...
# 正在转换中间文件：113640.SH...
# 正在转换中间文件：113641.SH...
# 正在转换中间文件：113642.SH...
# 正在转换中间文件：113643.SH...
# 正在转换中间文件：113644.SH...
# 正在转换中间文件：113646.SH...
# 正在转换中间文件：113647.SH...
# 正在转换中间文件：113648.SH...
# 正在转换中间文件：113649.SH...
# 正在转换中间文件：113650.SH...
# 正在转换中间文件：113651.SH...
# 正在转换中间文件：113652.SH...
# 正在转换中间文件：113653.SH...
# 正在转换中间文件：113654.SH...
# 正在转换中间文件：113655.SH...
# 正在转换中间文件：113656.SH...
# 正在转换中间文件：113657.SH...
# 正在转换中间文件：113658.SH...
# 正在转换中间文件：113659.SH...
# 正在转换中间文件：113660.SH...
# 正在转换中间文件：113661.SH...
# 正在转换中间文件：113662.SH...
# 正在转换中间文件：113663.SH...
# 正在转换中间文件：113664.SH...
# 正在转换中间文件：113665.SH...
# 正在转换中间文件：113666.SH...
# 正在转换中间文件：113667.SH...
# 正在转换中间文件：113668.SH...
# 正在转换中间文件：113669.SH...
# 正在转换中间文件：113670.SH...
# 正在转换中间文件：113671.SH...
# 正在转换中间文件：113672.SH...
# 正在转换中间文件：113673.SH...
# 正在转换中间文件：113674.SH...
# 正在转换中间文件：113675.SH...
# 正在转换中间文件：113676.SH...
# 正在转换中间文件：113677.SH...
# 正在转换中间文件：113678.SH...
# 正在转换中间文件：113679.SH...
# 正在转换中间文件：113680.SH...
# 正在转换中间文件：113681.SH...
# 正在转换中间文件：113682.SH...
# 正在转换中间文件：113683.SH...
# 正在转换中间文件：113684.SH...
# 正在转换中间文件：113685.SH...
# 正在转换中间文件：113686.SH...
# 正在转换中间文件：113687.SH...
# 正在转换中间文件：113688.SH...
# 正在转换中间文件：113689.SH...
# 正在转换中间文件：113690.SH...
# 正在转换中间文件：113691.SH...
# 正在转换中间文件：113692.SH...
# 正在转换中间文件：113693.SH...
# 正在转换中间文件：113694.SH...
# 正在转换中间文件：118000.SH...
# 正在转换中间文件：118001.SH...
# 正在转换中间文件：118002.SH...
# 正在转换中间文件：118003.SH...
# 正在转换中间文件：118004.SH...
# 正在转换中间文件：118005.SH...
# 正在转换中间文件：118006.SH...
# 正在转换中间文件：118007.SH...
# 正在转换中间文件：118008.SH...
# 正在转换中间文件：118009.SH...
# 正在转换中间文件：118010.SH...
# 正在转换中间文件：118011.SH...
# 正在转换中间文件：118012.SH...
# 正在转换中间文件：118013.SH...
# 正在转换中间文件：118014.SH...
# 正在转换中间文件：118015.SH...
# 正在转换中间文件：118016.SH...
# 正在转换中间文件：118017.SH...
# 正在转换中间文件：118018.SH...
# 正在转换中间文件：118019.SH...
# 正在转换中间文件：118020.SH...
# 正在转换中间文件：118021.SH...
# 正在转换中间文件：118022.SH...
# 正在转换中间文件：118023.SH...
# 正在转换中间文件：118024.SH...
# 正在转换中间文件：118025.SH...
# 正在转换中间文件：118026.SH...
# 正在转换中间文件：118027.SH...
# 正在转换中间文件：118028.SH...
# 正在转换中间文件：118029.SH...
# 正在转换中间文件：118030.SH...
# 正在转换中间文件：118031.SH...
# 正在转换中间文件：118032.SH...
# 正在转换中间文件：118033.SH...
# 正在转换中间文件：118034.SH...
# 正在转换中间文件：118035.SH...
# 正在转换中间文件：118036.SH...
# 正在转换中间文件：118037.SH...
# 正在转换中间文件：118038.SH...
# 正在转换中间文件：118039.SH...
# 正在转换中间文件：118040.SH...
# 正在转换中间文件：118041.SH...
# 正在转换中间文件：118042.SH...
# 正在转换中间文件：118043.SH...
# 正在转换中间文件：118044.SH...
# 正在转换中间文件：118045.SH...
# 正在转换中间文件：118046.SH...
# 正在转换中间文件：118048.SH...
# 正在转换中间文件：118049.SH...
# 正在转换中间文件：118050.SH...
# 正在转换中间文件：118051.SH...
# 正在转换中间文件：118052.SH...
# 正在转换中间文件：118053.SH...
# 正在转换中间文件：118054.SH...
# 正在转换中间文件：118055.SH...
# 正在转换中间文件：123002.SZ...
# 正在转换中间文件：123004.SZ...
# 正在转换中间文件：123010.SZ...
# 正在转换中间文件：123011.SZ...
# 正在转换中间文件：123012.SZ...
# 正在转换中间文件：123013.SZ...
# 正在转换中间文件：123014.SZ...
# 正在转换中间文件：123015.SZ...
# 正在转换中间文件：123018.SZ...
# 正在转换中间文件：123022.SZ...
# 正在转换中间文件：123023.SZ...
# 正在转换中间文件：123024.SZ...
# 正在转换中间文件：123025.SZ...
# 正在转换中间文件：123027.SZ...
# 正在转换中间文件：123029.SZ...
# 正在转换中间文件：123031.SZ...
# 正在转换中间文件：123034.SZ...
# 正在转换中间文件：123035.SZ...
# 正在转换中间文件：123038.SZ...
# 正在转换中间文件：123039.SZ...
# 正在转换中间文件：123042.SZ...
# 正在转换中间文件：123043.SZ...
# 正在转换中间文件：123044.SZ...
# 正在转换中间文件：123045.SZ...
# 正在转换中间文件：123046.SZ...
# 正在转换中间文件：123048.SZ...
# 正在转换中间文件：123049.SZ...
# 正在转换中间文件：123050.SZ...
# 正在转换中间文件：123052.SZ...
# 正在转换中间文件：123053.SZ...
# 正在转换中间文件：123054.SZ...
# 正在转换中间文件：123056.SZ...
# 正在转换中间文件：123057.SZ...
# 正在转换中间文件：123059.SZ...
# 正在转换中间文件：123060.SZ...
# 正在转换中间文件：123061.SZ...
# 正在转换中间文件：123062.SZ...
# 正在转换中间文件：123063.SZ...
# 正在转换中间文件：123064.SZ...
# 正在转换中间文件：123065.SZ...
# 正在转换中间文件：123067.SZ...
# 正在转换中间文件：123070.SZ...
# 正在转换中间文件：123071.SZ...
# 正在转换中间文件：123072.SZ...
# 正在转换中间文件：123073.SZ...
# 正在转换中间文件：123075.SZ...
# 正在转换中间文件：123076.SZ...
# 正在转换中间文件：123077.SZ...
# 正在转换中间文件：123078.SZ...
# 正在转换中间文件：123080.SZ...
# 正在转换中间文件：123082.SZ...
# 正在转换中间文件：123083.SZ...
# 正在转换中间文件：123084.SZ...
# 正在转换中间文件：123085.SZ...
# 正在转换中间文件：123086.SZ...
# 正在转换中间文件：123087.SZ...
# 正在转换中间文件：123088.SZ...
# 正在转换中间文件：123089.SZ...
# 正在转换中间文件：123090.SZ...
# 正在转换中间文件：123091.SZ...
# 正在转换中间文件：123092.SZ...
# 正在转换中间文件：123093.SZ...
# 正在转换中间文件：123096.SZ...
# 正在转换中间文件：123097.SZ...
# 正在转换中间文件：123098.SZ...
# 正在转换中间文件：123099.SZ...
# 正在转换中间文件：123100.SZ...
# 正在转换中间文件：123101.SZ...
# 正在转换中间文件：123103.SZ...
# 正在转换中间文件：123104.SZ...
# 正在转换中间文件：123105.SZ...
# 正在转换中间文件：123106.SZ...
# 正在转换中间文件：123107.SZ...
# 正在转换中间文件：123108.SZ...
# 正在转换中间文件：123109.SZ...
# 正在转换中间文件：123110.SZ...
# 正在转换中间文件：123111.SZ...
# 正在转换中间文件：123112.SZ...
# 正在转换中间文件：123113.SZ...
# 正在转换中间文件：123114.SZ...
# 正在转换中间文件：123115.SZ...
# 正在转换中间文件：123116.SZ...
# 正在转换中间文件：123117.SZ...
# 正在转换中间文件：123118.SZ...
# 正在转换中间文件：123119.SZ...
# 正在转换中间文件：123120.SZ...
# 正在转换中间文件：123121.SZ...
# 正在转换中间文件：123122.SZ...
# 正在转换中间文件：123123.SZ...
# 正在转换中间文件：123124.SZ...
# 正在转换中间文件：123125.SZ...
# 正在转换中间文件：123126.SZ...
# 正在转换中间文件：123127.SZ...
# 正在转换中间文件：123128.SZ...
# 正在转换中间文件：123129.SZ...
# 正在转换中间文件：123130.SZ...
# 正在转换中间文件：123131.SZ...
# 正在转换中间文件：123132.SZ...
# 正在转换中间文件：123133.SZ...
# 正在转换中间文件：123134.SZ...
# 正在转换中间文件：123135.SZ...
# 正在转换中间文件：123136.SZ...
# 正在转换中间文件：123137.SZ...
# 正在转换中间文件：123138.SZ...
# 正在转换中间文件：123139.SZ...
# 正在转换中间文件：123140.SZ...
# 正在转换中间文件：123141.SZ...
# 正在转换中间文件：123142.SZ...
# 正在转换中间文件：123143.SZ...
# 正在转换中间文件：123144.SZ...
# 正在转换中间文件：123145.SZ...
# 正在转换中间文件：123146.SZ...
# 正在转换中间文件：123147.SZ...
# 正在转换中间文件：123148.SZ...
# 正在转换中间文件：123149.SZ...
# 正在转换中间文件：123150.SZ...
# 正在转换中间文件：123151.SZ...
# 正在转换中间文件：123152.SZ...
# 正在转换中间文件：123153.SZ...
# 正在转换中间文件：123154.SZ...
# 正在转换中间文件：123155.SZ...
# 正在转换中间文件：123156.SZ...
# 正在转换中间文件：123157.SZ...
# 正在转换中间文件：123158.SZ...
# 正在转换中间文件：123159.SZ...
# 正在转换中间文件：123160.SZ...
# 正在转换中间文件：123161.SZ...
# 正在转换中间文件：123162.SZ...
# 正在转换中间文件：123163.SZ...
# 正在转换中间文件：123164.SZ...
# 正在转换中间文件：123165.SZ...
# 正在转换中间文件：123166.SZ...
# 正在转换中间文件：123167.SZ...
# 正在转换中间文件：123168.SZ...
# 正在转换中间文件：123169.SZ...
# 正在转换中间文件：123170.SZ...
# 正在转换中间文件：123171.SZ...
# 正在转换中间文件：123172.SZ...
# 正在转换中间文件：123173.SZ...
# 正在转换中间文件：123174.SZ...
# 正在转换中间文件：123175.SZ...
# 正在转换中间文件：123176.SZ...
# 正在转换中间文件：123177.SZ...
# 正在转换中间文件：123178.SZ...
# 正在转换中间文件：123179.SZ...
# 正在转换中间文件：123180.SZ...
# 正在转换中间文件：123181.SZ...
# 正在转换中间文件：123182.SZ...
# 正在转换中间文件：123183.SZ...
# 正在转换中间文件：123184.SZ...
# 正在转换中间文件：123185.SZ...
# 正在转换中间文件：123186.SZ...
# 正在转换中间文件：123187.SZ...
# 正在转换中间文件：123188.SZ...
# 正在转换中间文件：123189.SZ...
# 正在转换中间文件：123190.SZ...
# 正在转换中间文件：123191.SZ...
# 正在转换中间文件：123192.SZ...
# 正在转换中间文件：123193.SZ...
# 正在转换中间文件：123194.SZ...
# 正在转换中间文件：123195.SZ...
# 正在转换中间文件：123196.SZ...
# 正在转换中间文件：123197.SZ...
# 正在转换中间文件：123198.SZ...
# 正在转换中间文件：123199.SZ...
# 正在转换中间文件：123200.SZ...
# 正在转换中间文件：123201.SZ...
# 正在转换中间文件：123202.SZ...
# 正在转换中间文件：123203.SZ...
# 正在转换中间文件：123204.SZ...
# 正在转换中间文件：123205.SZ...
# 正在转换中间文件：123206.SZ...
# 正在转换中间文件：123207.SZ...
# 正在转换中间文件：123208.SZ...
# 正在转换中间文件：123209.SZ...
# 正在转换中间文件：123210.SZ...
# 正在转换中间文件：123211.SZ...
# 正在转换中间文件：123212.SZ...
# 正在转换中间文件：123213.SZ...
# 正在转换中间文件：123214.SZ...
# 正在转换中间文件：123215.SZ...
# 正在转换中间文件：123216.SZ...
# 正在转换中间文件：123217.SZ...
# 正在转换中间文件：123218.SZ...
# 正在转换中间文件：123219.SZ...
# 正在转换中间文件：123220.SZ...
# 正在转换中间文件：123221.SZ...
# 正在转换中间文件：123222.SZ...
# 正在转换中间文件：123223.SZ...
# 正在转换中间文件：123224.SZ...
# 正在转换中间文件：123225.SZ...
# 正在转换中间文件：123226.SZ...
# 正在转换中间文件：123227.SZ...
# 正在转换中间文件：123228.SZ...
# 正在转换中间文件：123229.SZ...
# 正在转换中间文件：123230.SZ...
# 正在转换中间文件：123231.SZ...
# 正在转换中间文件：123232.SZ...
# 正在转换中间文件：123233.SZ...
# 正在转换中间文件：123234.SZ...
# 正在转换中间文件：123235.SZ...
# 正在转换中间文件：123236.SZ...
# 正在转换中间文件：123237.SZ...
# 正在转换中间文件：123238.SZ...
# 正在转换中间文件：123239.SZ...
# 正在转换中间文件：123240.SZ...
# 正在转换中间文件：123241.SZ...
# 正在转换中间文件：123242.SZ...
# 正在转换中间文件：123243.SZ...
# 正在转换中间文件：123244.SZ...
# 正在转换中间文件：123245.SZ...
# 正在转换中间文件：123246.SZ...
# 正在转换中间文件：123247.SZ...
# 正在转换中间文件：123248.SZ...
# 正在转换中间文件：123249.SZ...
# 正在转换中间文件：123250.SZ...
# 正在转换中间文件：123251.SZ...
# 正在转换中间文件：123252.SZ...
# 正在转换中间文件：123253.SZ...
# 正在转换中间文件：123254.SZ...
# 正在转换中间文件：123255.SZ...
# 正在转换中间文件：123256.SZ...
# 正在转换中间文件：123257.SZ...
# 正在转换中间文件：124004.SZ...
# 正在转换中间文件：124005.SZ...
# 正在转换中间文件：124017.SZ...
# 正在转换中间文件：127003.SZ...
# 正在转换中间文件：127004.SZ...
# 正在转换中间文件：127005.SZ...
# 正在转换中间文件：127006.SZ...
# 正在转换中间文件：127007.SZ...
# 正在转换中间文件：127011.SZ...
# 正在转换中间文件：127012.SZ...
# 正在转换中间文件：127013.SZ...
# 正在转换中间文件：127014.SZ...
# 正在转换中间文件：127015.SZ...
# 正在转换中间文件：127016.SZ...
# 正在转换中间文件：127017.SZ...
# 正在转换中间文件：127018.SZ...
# 正在转换中间文件：127019.SZ...
# 正在转换中间文件：127020.SZ...
# 正在转换中间文件：127021.SZ...
# 正在转换中间文件：127022.SZ...
# 正在转换中间文件：127024.SZ...
# 正在转换中间文件：127025.SZ...
# 正在转换中间文件：127026.SZ...
# 正在转换中间文件：127027.SZ...
# 正在转换中间文件：127028.SZ...
# 正在转换中间文件：127029.SZ...
# 正在转换中间文件：127030.SZ...
# 正在转换中间文件：127031.SZ...
# 正在转换中间文件：127032.SZ...
# 正在转换中间文件：127033.SZ...
# 正在转换中间文件：127034.SZ...
# 正在转换中间文件：127035.SZ...
# 正在转换中间文件：127036.SZ...
# 正在转换中间文件：127037.SZ...
# 正在转换中间文件：127038.SZ...
# 正在转换中间文件：127039.SZ...
# 正在转换中间文件：127040.SZ...
# 正在转换中间文件：127041.SZ...
# 正在转换中间文件：127042.SZ...
# 正在转换中间文件：127043.SZ...
# 正在转换中间文件：127044.SZ...
# 正在转换中间文件：127045.SZ...
# 正在转换中间文件：127046.SZ...
# 正在转换中间文件：127047.SZ...
# 正在转换中间文件：127048.SZ...
# 正在转换中间文件：127049.SZ...
# 正在转换中间文件：127050.SZ...
# 正在转换中间文件：127051.SZ...
# 正在转换中间文件：127052.SZ...
# 正在转换中间文件：127053.SZ...
# 正在转换中间文件：127054.SZ...
# 正在转换中间文件：127055.SZ...
# 正在转换中间文件：127056.SZ...
# 正在转换中间文件：127057.SZ...
# 正在转换中间文件：127058.SZ...
# 正在转换中间文件：127059.SZ...
# 正在转换中间文件：127060.SZ...
# 正在转换中间文件：127061.SZ...
# 正在转换中间文件：127062.SZ...
# 正在转换中间文件：127063.SZ...
# 正在转换中间文件：127064.SZ...
# 正在转换中间文件：127065.SZ...
# 正在转换中间文件：127066.SZ...
# 正在转换中间文件：127067.SZ...
# 正在转换中间文件：127068.SZ...
# 正在转换中间文件：127069.SZ...
# 正在转换中间文件：127070.SZ...
# 正在转换中间文件：127071.SZ...
# 正在转换中间文件：127072.SZ...
# 正在转换中间文件：127073.SZ...
# 正在转换中间文件：127074.SZ...
# 正在转换中间文件：127075.SZ...
# 正在转换中间文件：127076.SZ...
# 正在转换中间文件：127077.SZ...
# 正在转换中间文件：127078.SZ...
# 正在转换中间文件：127079.SZ...
# 正在转换中间文件：127080.SZ...
# 正在转换中间文件：127081.SZ...
# 正在转换中间文件：127082.SZ...
# 正在转换中间文件：127083.SZ...
# 正在转换中间文件：127084.SZ...
# 正在转换中间文件：127085.SZ...
# 正在转换中间文件：127086.SZ...
# 正在转换中间文件：127087.SZ...
# 正在转换中间文件：127088.SZ...
# 正在转换中间文件：127089.SZ...
# 正在转换中间文件：127090.SZ...
# 正在转换中间文件：127091.SZ...
# 正在转换中间文件：127092.SZ...
# 正在转换中间文件：127093.SZ...
# 正在转换中间文件：127094.SZ...
# 正在转换中间文件：127095.SZ...
# 正在转换中间文件：127096.SZ...
# 正在转换中间文件：127097.SZ...
# 正在转换中间文件：127098.SZ...
# 正在转换中间文件：127099.SZ...
# 正在转换中间文件：127100.SZ...
# 正在转换中间文件：127101.SZ...
# 正在转换中间文件：127102.SZ...
# 正在转换中间文件：127103.SZ...
# 正在转换中间文件：127104.SZ...
# 正在转换中间文件：127105.SZ...
# 正在转换中间文件：127106.SZ...
# 正在转换中间文件：127107.SZ...
# 正在转换中间文件：127108.SZ...
# 正在转换中间文件：127109.SZ...
# 正在转换中间文件：128013.SZ...
# 正在转换中间文件：128014.SZ...
# 正在转换中间文件：128015.SZ...
# 正在转换中间文件：128017.SZ...
# 正在转换中间文件：128021.SZ...
# 正在转换中间文件：128022.SZ...
# 正在转换中间文件：128023.SZ...
# 正在转换中间文件：128025.SZ...
# 正在转换中间文件：128026.SZ...
# 正在转换中间文件：128029.SZ...
# 正在转换中间文件：128030.SZ...
# 正在转换中间文件：128033.SZ...
# 正在转换中间文件：128034.SZ...
# 正在转换中间文件：128035.SZ...
# 正在转换中间文件：128036.SZ...
# 正在转换中间文件：128037.SZ...
# 正在转换中间文件：128039.SZ...
# 正在转换中间文件：128040.SZ...
# 正在转换中间文件：128041.SZ...
# 正在转换中间文件：128042.SZ...
# 正在转换中间文件：128044.SZ...
# 正在转换中间文件：128046.SZ...
# 正在转换中间文件：128048.SZ...
# 正在转换中间文件：128049.SZ...
# 正在转换中间文件：128050.SZ...
# 正在转换中间文件：128053.SZ...
# 正在转换中间文件：128056.SZ...
# 正在转换中间文件：128062.SZ...
# 正在转换中间文件：128063.SZ...
# 正在转换中间文件：128066.SZ...
# 正在转换中间文件：128069.SZ...
# 正在转换中间文件：128070.SZ...
# 正在转换中间文件：128071.SZ...
# 正在转换中间文件：128072.SZ...
# 正在转换中间文件：128073.SZ...
# 正在转换中间文件：128074.SZ...
# 正在转换中间文件：128075.SZ...
# 正在转换中间文件：128076.SZ...
# 正在转换中间文件：128078.SZ...
# 正在转换中间文件：128079.SZ...
# 正在转换中间文件：128081.SZ...
# 正在转换中间文件：128082.SZ...
# 正在转换中间文件：128083.SZ...
# 正在转换中间文件：128085.SZ...
# 正在转换中间文件：128087.SZ...
# 正在转换中间文件：128090.SZ...
# 正在转换中间文件：128091.SZ...
# 正在转换中间文件：128093.SZ...
# 正在转换中间文件：128094.SZ...
# 正在转换中间文件：128095.SZ...
# 正在转换中间文件：128096.SZ...
# 正在转换中间文件：128097.SZ...
# 正在转换中间文件：128100.SZ...
# 正在转换中间文件：128101.SZ...
# 正在转换中间文件：128103.SZ...
# 正在转换中间文件：128105.SZ...
# 正在转换中间文件：128106.SZ...
# 正在转换中间文件：128107.SZ...
# 正在转换中间文件：128108.SZ...
# 正在转换中间文件：128109.SZ...
# 正在转换中间文件：128111.SZ...
# 正在转换中间文件：128113.SZ...
# 正在转换中间文件：128114.SZ...
# 正在转换中间文件：128116.SZ...
# 正在转换中间文件：128117.SZ...
# 正在转换中间文件：128118.SZ...
# 正在转换中间文件：128119.SZ...
# 正在转换中间文件：128120.SZ...
# 正在转换中间文件：128121.SZ...
# 正在转换中间文件：128122.SZ...
# 正在转换中间文件：128123.SZ...
# 正在转换中间文件：128124.SZ...
# 正在转换中间文件：128125.SZ...
# 正在转换中间文件：128127.SZ...
# 正在转换中间文件：128128.SZ...
# 正在转换中间文件：128129.SZ...
# 正在转换中间文件：128130.SZ...
# 正在转换中间文件：128131.SZ...
# 正在转换中间文件：128132.SZ...
# 正在转换中间文件：128133.SZ...
# 正在转换中间文件：128134.SZ...
# 正在转换中间文件：128135.SZ...
# 正在转换中间文件：128136.SZ...
# 正在转换中间文件：128137.SZ...
# 正在转换中间文件：128138.SZ...
# 正在转换中间文件：128139.SZ...
# 正在转换中间文件：128140.SZ...
# 正在转换中间文件：128141.SZ...
# 正在转换中间文件：128142.SZ...
# 正在转换中间文件：128143.SZ...
# 正在转换中间文件：128144.SZ...
# 正在转换中间文件：128145.SZ...

# %%
'''
csv转bin
其中
E:/PY_qlib_env/.venv/Scripts/python.exe 指python路径
E:/PY_qlib_env/.venv/Lib/site-packages/qlib/scripts/dump_bin.py dump_all 指qlib的dump_bin.py路径
--csv_path 原始数据路径
--qlib_dir 转换后数据路径
--freq 1min 转换后数据频率
--date_field_name datetime 转换后数据时间字段
--symbol_field_name instrument 转换后数据股票代码字段
--include_fields open,high,low,close,volume 转换后数据包含字段
'''
print(f"正在执行把csv文件转换为bin文件...")
subprocess.run(f'D:/anaconda/envs/py10/python.exe C:/Users/tantra/Desktop/data/.venv/Lib/site-packages/qlib/scripts/dump_bin.py dump_all --csv_path min1_data_mid --qlib_dir min1_data_qlib --freq 1min --date_field_name datetime --symbol_field_name instrument --include_fields open,high,low,close,volume,amount')#,marketcap,new,ST,CONVERTIBLEPREMIUMRATE')#pre_close,TURNOVERRATE,new,ST')
# Out:
# 正在执行把csv文件转换为bin文件...
# CompletedProcess(args='D:/anaconda/envs/py10/python.exe C:/Users/tantra/Desktop/data/.venv/Lib/site-packages/qlib/scripts/dump_bin.py dump_all --csv_path min1_data_mid --qlib_dir min1_data_qlib --freq 1min --date_field_name datetime --symbol_field_name instrument --include_fields open,high,low,close,volume,amount', returncode=0)
